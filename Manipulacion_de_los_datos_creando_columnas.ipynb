# %% [markdown]
# <a href="https://colab.research.google.com/github/ollin02/Pandas/blob/main/Manipulacion_de_los_datos_creando_columnas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Hay varias formas de crear columnas en un DataFrame en Pandas. Algunos ejemplos son:
#
# 1 - Asignación directa de valores a una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = [7, 8, 9]

df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# 2 - Creación de una columna a partir de operaciones entre otras columnas:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'] + df['B']
df
# Out:
#    A  B  C
# 0  1  4  5
# 1  2  5  7
# 2  3  6  9

# %% [markdown]
# 3 - Uso del método assign() para crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df = df.assign(C=[7, 8, 9])
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# 4 - Uso del método apply() para aplicar una función a una columna existente y crear una nueva columna:

# %%
import pandas as pd

df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})
df['C'] = df['A'].apply(lambda x: x * 2)
df
# Out:
#    A  B  C
# 0  1  4  2
# 1  2  5  4
# 2  3  6  6
